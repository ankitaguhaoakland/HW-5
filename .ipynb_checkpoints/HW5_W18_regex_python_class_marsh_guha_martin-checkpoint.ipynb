# %% [markdown]
# # HW5 - Regex, Python, Classifiers
#
# There are three problems in this assignment.
#
# 1. Text file processing with Python and regex
# 1. Basic EDA with pandas and matplotlib
# 1. Building classifier models with R and/or Python
#
# The first two problems use data on YouTube statistics related to top trending videos. The third uses different data.
#
#
# ### Deliverables
#
# * For Problem 1 you'll end up with one Python script file (.py). If you insist, you could write your function in this notebook but I recommend using PyCharm. You'll also end up with an output csv file that you'll turn in.
# * This notebook containing your work for the Problems 2. Make sure that you've run all of your cells but that you've also organized your files so that if I have to rerun something, it will all work.
# * Whatever files you create for Problem 3.
#
# Please organize your deliverables within a folder in some coherent way. Include a README.md file to tell me where to find your work and how to test it (mostly for Problem 3).

# %% [markdown]
# ## Problem 1 - Text file processing with Python
#
# See https://www.kaggle.com/datasnaek/youtube-new for a description of this dataset. I've
# provided the file `USvideos.csv` in the `data` folder.
#
# Now you are going to write a short Python script to read the
# `USvideos.csv` file and do some basic text file manipulation.
#
# I'm giving you some skeleton code that you are free to use if you wish. The
# skeleton code file is called `process_youtube_stats_skeleton.py`. **I highly
# encourage you to use it as it lays out the steps needed and has many useful
# code snippets and comments.**
#
# You should also review the process_apache_log.py file that
# we first saw in the Downloads for the regex session - I've included that as well. You can use
# these files as a starting point for ideas or even just edit and add/delete code
# as needed to accomplish this last task. Your new Python file should be named:
#
#     process_youtube_stats_yourname.py # Obviously replacing "yourname" appropriately
#
# Your job is to modify the skeleton file (or create a new program
# from scratch) to accomplish the following.
#
# ### The big picture
# The big picture is that you are going to read the file,
# use regex to find lines having a certain category_id value and some values on
# that line, update some counters, and write out the lines of interest to a new file.
#
# I highly recommend you check out the Kaggle site for this dataset and snoop the data
# yourself with a text editor.
#
# **You must use regex for any text pattern matching.**
#
# ### The more detailed picture
#
# Here are the detailed requirements:
#
# * Your function `def` should look like the following (see the skeleton code):
#
#       `def process_youtube(fn_youtube , fn_out):`
#
# Your function will take an input filename and an output filename as arguments.
#
# * You need to loop over the lines in the input file and use regex to determine if each
# line has a value of 28 for the category_id field. Yes, you can hard code the
# 28 into your regex pattern. Category_id 28 is Science & Technology.
#
# For those lines that ARE from category 28:
#
# * Increment a counter representing the number of lines matched.
# * Using the captured trending_date as a dictionary key, update the dictionary
# of counts by trending_date
# * Store the line in a master list so that we can write out these lines at the end.
#
# For those lines that ARE NOT from category 28:
#
# * Increment a counter representing the number of lines NOT matched.
#
# After all lines processed,
# write out a message with the totals. Here's the last few lines of my output.
#
#     18.01.01:	   10 videos
#     18.26.02:	    9 videos
#     18.05.02:	   14 videos
#     18.08.01:	   11 videos
#     17.22.12:	    8 videos
#
#     Num lines matched --> 1233
#     Num lines not matched --> 26089
#
#
# Remember that dictionaries are not sorted and so you're output of the counts by date
# may differ in the order printed out from mine.
#
# Finally, write out the matched lines that you stored in a list.
# There are several ways to write out a list of strings to a file. Google and
# StackOverflow are your friend.
#
# Again, see the skeleton code.
#
#
# **HACKER EXTRA:**
#
# To make this program even better, change the function so that you can pass in
# any category_id to use as the filter instead of having 28 hard coded in as it is now.

# %% [markdown]
# ## Problem 2 - EDA with pandas and plotting libraries

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import math
import re
import csv

# %% [markdown]
# ### Step 1 - Read in the data
# Looks like there are two datetime related fields. Let's see if pandas can parse them
# correctly.

# %%
# Read the data
USvideos = pd.read_csv('data/USvideos.csv', parse_dates=['trending_date', 'publish_time'])

# %%
# Check out the structure of the resulting DataFrame
USvideos.describe()
USvideos.head()
# Out:
#       video_id trending_date  \
# 0  2kyS6SvSYSE      17.14.11
# 1  1ZAPwfrtAFY      17.14.11
# 2  5qpjK5DgCt4      17.14.11
# 3  puqaWrEC7tY      17.14.11
# 4  d380meD0W0M      17.14.11
#
#                                                title          channel_title  \
# 0                 WE WANT TO TALK ABOUT OUR MARRIAGE           CaseyNeistat
# 1  The Trump Presidency: Last Week Tonight with J...        LastWeekTonight
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...           Rudy Mancuso
# 3                   Nickelback Lyrics: Real or Fake?  Good Mythical Morning
# 4                           I Dare You: GOING BALD!?               nigahiga
#
#    category_id        publish_time  \
# 0           22 2017-11-13 17:13:01
# 1           24 2017-11-13 07:30:00
# 2           23 2017-11-12 19:05:24
# 3           24 2017-11-13 11:00:04
# 4           24 2017-11-12 18:01:41
#
#                                                 tags    views   likes  \
# 0                                    SHANtell martin   748374   57527
# 1  last week tonight trump presidency|"last week ...  2418783   97185
# 2  racist superman|"rudy"|"mancuso"|"king"|"bach"...  3191434  146033
# 3  rhett and link|"gmm"|"good mythical morning"|"...   343168   10172
# 4  ryan|"higa"|"higatv"|"nigahiga"|"i dare you"|"...  2095731  132235
#
#    dislikes  comment_count                                  thumbnail_link  \
# 0      2966          15954  https://i.ytimg.com/vi/2kyS6SvSYSE/default.jpg
# 1      6146          12703  https://i.ytimg.com/vi/1ZAPwfrtAFY/default.jpg
# 2      5339           8181  https://i.ytimg.com/vi/5qpjK5DgCt4/default.jpg
# 3       666           2146  https://i.ytimg.com/vi/puqaWrEC7tY/default.jpg
# 4      1989          17518  https://i.ytimg.com/vi/d380meD0W0M/default.jpg
#
#    comments_disabled  ratings_disabled  video_error_or_removed  \
# 0              False             False                   False
# 1              False             False                   False
# 2              False             False                   False
# 3              False             False                   False
# 4              False             False                   False
#
#                                          description
# 0  SHANTELL'S CHANNEL - https://www.youtube.com/s...
# 1  One year after the presidential election, John...
# 2  WATCH MY PREVIOUS VIDEO ▶ \n\nSUBSCRIBE ► http...
# 3  Today we find out if Link is a Nickelback amat...
# 4  I know it's been a while since we did this sho...

# %% [markdown]
# **Question 2.1** Which of the date fields gets read in correctly as some sort of date or datetime field?
# The publish_date field is read in correctly, but the trending_date did not.

# %% [markdown]
# **Question 2.2** List the first 10 rows, rows 1500 through 1510, and the last 10 rows of the data frame. Use three separate code cells.

# %%
USvideos.head(10) #first 10 rows
# Out:
#       video_id trending_date  \
# 0  2kyS6SvSYSE      17.14.11
# 1  1ZAPwfrtAFY      17.14.11
# 2  5qpjK5DgCt4      17.14.11
# 3  puqaWrEC7tY      17.14.11
# 4  d380meD0W0M      17.14.11
# 5  gHZ1Qz0KiKM      17.14.11
# 6  39idVpFF7NQ      17.14.11
# 7  nc99ccSXST0      17.14.11
# 8  jr9QtXwC9vc      17.14.11
# 9  TUmyygCMMGA      17.14.11
#
#                                                title          channel_title  \
# 0                 WE WANT TO TALK ABOUT OUR MARRIAGE           CaseyNeistat
# 1  The Trump Presidency: Last Week Tonight with J...        LastWeekTonight
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...           Rudy Mancuso
# 3                   Nickelback Lyrics: Real or Fake?  Good Mythical Morning
# 4                           I Dare You: GOING BALD!?               nigahiga
# 5                              2 Weeks with iPhone X               iJustine
# 6          Roy Moore & Jeff Sessions Cold Open - SNL    Saturday Night Live
# 7                5 Ice Cream Gadgets put to the Test     CrazyRussianHacker
# 8  The Greatest Showman | Official Trailer 2 [HD]...       20th Century Fox
# 9  Why the rise of the robots won’t mean the end ...                    Vox
#
#    category_id        publish_time  \
# 0           22 2017-11-13 17:13:01
# 1           24 2017-11-13 07:30:00
# 2           23 2017-11-12 19:05:24
# 3           24 2017-11-13 11:00:04
# 4           24 2017-11-12 18:01:41
# 5           28 2017-11-13 19:07:23
# 6           24 2017-11-12 05:37:17
# 7           28 2017-11-12 21:50:37
# 8            1 2017-11-13 14:00:23
# 9           25 2017-11-13 13:45:16
#
#                                                 tags    views   likes  \
# 0                                    SHANtell martin   748374   57527
# 1  last week tonight trump presidency|"last week ...  2418783   97185
# 2  racist superman|"rudy"|"mancuso"|"king"|"bach"...  3191434  146033
# 3  rhett and link|"gmm"|"good mythical morning"|"...   343168   10172
# 4  ryan|"higa"|"higatv"|"nigahiga"|"i dare you"|"...  2095731  132235
# 5  ijustine|"week with iPhone X"|"iphone x"|"appl...   119180    9763
# 6  SNL|"Saturday Night Live"|"SNL Season 43"|"Epi...  2103417   15993
# 7  5 Ice Cream Gadgets|"Ice Cream"|"Cream Sandwic...   817732   23663
# 8  Trailer|"Hugh Jackman"|"Michelle Williams"|"Za...   826059    3543
# 9  vox.com|"vox"|"explain"|"shift change"|"future...   256426   12654
#
#    dislikes  comment_count                                  thumbnail_link  \
# 0      2966          15954  https://i.ytimg.com/vi/2kyS6SvSYSE/default.jpg
# 1      6146          12703  https://i.ytimg.com/vi/1ZAPwfrtAFY/default.jpg
# 2      5339           8181  https://i.ytimg.com/vi/5qpjK5DgCt4/default.jpg
# 3       666           2146  https://i.ytimg.com/vi/puqaWrEC7tY/default.jpg
# 4      1989          17518  https://i.ytimg.com/vi/d380meD0W0M/default.jpg
# 5       511           1434  https://i.ytimg.com/vi/gHZ1Qz0KiKM/default.jpg
# 6      2445           1970  https://i.ytimg.com/vi/39idVpFF7NQ/default.jpg
# 7       778           3432  https://i.ytimg.com/vi/nc99ccSXST0/default.jpg
# 8       119            340  https://i.ytimg.com/vi/jr9QtXwC9vc/default.jpg
# 9      1363           2368  https://i.ytimg.com/vi/TUmyygCMMGA/default.jpg
#
#    comments_disabled  ratings_disabled  video_error_or_removed  \
# 0              False             False                   False
# 1              False             False                   False
# 2              False             False                   False
# 3              False             False                   False
# 4              False             False                   False
# 5              False             False                   False
# 6              False             False                   False
# 7              False             False                   False
# 8              False             False                   False
# 9              False             False                   False
#
#                                          description
# 0  SHANTELL'S CHANNEL - https://www.youtube.com/s...
# 1  One year after the presidential election, John...
# 2  WATCH MY PREVIOUS VIDEO ▶ \n\nSUBSCRIBE ► http...
# 3  Today we find out if Link is a Nickelback amat...
# 4  I know it's been a while since we did this sho...
# 5  Using the iPhone for the past two weeks -- her...
# 6  Embattled Alabama Senate candidate Roy Moore (...
# 7  Ice Cream Pint Combination Lock - http://amzn....
# 8  Inspired by the imagination of P.T. Barnum, Th...
# 9  For now, at least, we have better things to wo...

# %%
USvideos[1500:1511] #rows 1500 to 1510
# Out:
#          video_id trending_date  \
# 1500  3jtjkXSvuJw      17.21.11
# 1501  qS6LoRYUdhw      17.21.11
# 1502  kz3MEd1Jr0Q      17.21.11
# 1503  wJh-jurxmGQ      17.21.11
# 1504  8-u5nd2GqNE      17.21.11
# 1505  TsYGNNPQ3ZU      17.21.11
# 1506  fQvGSkTYJSE      17.21.11
# 1507  FKA-Jy6nuE0      17.21.11
# 1508  JLOFZoBJnd8      17.21.11
# 1509  duRDizP0gHQ      17.21.11
# 1510  dcipHnWcB0w      17.21.11
#
#                                                   title         channel_title  \
# 1500              Try Not to Laugh at This Silly Kitten           Kitten Lady
# 1501  What Is The Most Dangerous Drug In The World? ...           AsapSCIENCE
# 1502  Steve Aoki x Lauren Jauregui - All Night (Lyri...           Ultra Music
# 1503  Will Ferrell Left Speechless as Mark Wahlberg ...  Good Morning Britain
# 1504        The Secret Protocol for When the Queen Dies   Half as Interesting
# 1505                       KEEP ME COMING by SUPERFRUIT            SUPERFRUIT
# 1506  Elon Musk Gives First Look At Tesla's Electric...          Tech Insider
# 1507    Tim McGraw, Faith Hill - Cowboy Lullaby (Audio)       TimandFaithVEVO
# 1508               TRANSFORMING SUMMER MCKEEN INTO ME!!        Maddie Ziegler
# 1509  Bob Saget Hiccups Uncontrollably While Eating ...        First We Feast
# 1510  Kim Kardashian's Surrogate Didn't Know Whose B...      The Real Daytime
#
#       category_id        publish_time  \
# 1500           15 2017-11-17 22:40:58
# 1501           28 2017-11-16 17:38:54
# 1502           10 2017-11-17 15:01:54
# 1503           24 2017-11-17 11:22:12
# 1504           27 2017-11-16 15:30:00
# 1505           24 2017-11-17 17:01:09
# 1506            2 2017-11-17 14:36:39
# 1507           10 2017-11-17 08:00:01
# 1508           24 2017-11-18 01:40:29
# 1509           26 2017-11-16 16:00:05
# 1510           24 2017-11-16 18:03:56
#
#                                                    tags    views  likes  \
# 1500  fizz|"funniest"|"silliest"|"silly"|"funny"|"to...    71637   6306
# 1501  Most dangerous drug|"Most lethal drug"|"Is alc...  1137271  44392
# 1502  ultra records|"ultra music"|"ultrarecords"|"ul...  1000754  63603
# 1503  good morning britain|"breakfast show"|"news"|"...    80663    443
# 1504  the|"secret"|"protocal"|"procedure"|"process"|...  1021443  25927
# 1505  superfruit|"super"|"fruit"|"scott"|"hoying"|"m...   165353  15688
# 1506  Tech Insider|"TI"|"Tech"|"Science"|"Innovation...   789872   8909
# 1507  the rest of our life|"soul to soul"|"soul 2 so...    65746   1570
# 1508  maddie|"ziegler"|"summer"|"mckeen"|"dancer"|"c...   442977  25056
# 1509  bob saget|"hot ones"|"sean evans"|"spicy wings...  1043202  42380
# 1510  the real|"daytime"|"talk show"|"women"|"tamera...   654025   5741
#
#       dislikes  comment_count                                  thumbnail_link  \
# 1500        16            626  https://i.ytimg.com/vi/3jtjkXSvuJw/default.jpg
# 1501       682           3949  https://i.ytimg.com/vi/qS6LoRYUdhw/default.jpg
# 1502       810           2884  https://i.ytimg.com/vi/kz3MEd1Jr0Q/default.jpg
# 1503        56              0  https://i.ytimg.com/vi/wJh-jurxmGQ/default.jpg
# 1504       805           4476  https://i.ytimg.com/vi/8-u5nd2GqNE/default.jpg
# 1505       172           1554  https://i.ytimg.com/vi/TsYGNNPQ3ZU/default.jpg
# 1506       633           2917  https://i.ytimg.com/vi/fQvGSkTYJSE/default.jpg
# 1507        72             49  https://i.ytimg.com/vi/FKA-Jy6nuE0/default.jpg
# 1508       255           1160  https://i.ytimg.com/vi/JLOFZoBJnd8/default.jpg
# 1509       768           5825  https://i.ytimg.com/vi/duRDizP0gHQ/default.jpg
# 1510       452            569  https://i.ytimg.com/vi/dcipHnWcB0w/default.jpg
#
#       comments_disabled  ratings_disabled  video_error_or_removed  \
# 1500              False             False                   False
# 1501              False             False                   False
# 1502              False             False                   False
# 1503               True             False                   False
# 1504              False             False                   False
# 1505              False             False                   False
# 1506              False             False                   False
# 1507              False             False                   False
# 1508              False             False                   False
# 1509              False             False                   False
# 1510              False             False                   False
#
#                                             description
# 1500  Fizz is one of the funniest kittens I've ever ...
# 1501  From drug overdose to the war on drugs,  what'...
# 1502  Steve Aoki x Lauren Jauregui - All Night\nStev...
# 1503  Subscribe now for more! http://bit.ly/1NbomQa\...
# 1504  Raise money for charity just by browsing the i...
# 1505  FUTURE FRIENDS - http://smarturl.it/FutureFrie...
# 1506  Tesla CEO Elon Musk promised the company's fir...
# 1507  Get  Cowboy Lullaby on the new album from Tim ...
# 1508  Thank you guys for watching!!! Me and summer h...
# 1509  Bob Saget became a household name as Danny Tan...
# 1510               It’s a Kim Kardashian West TAKEOVER!

# %%
USvideos[-10:] #last 10 rows
# Out:
#           video_id trending_date  \
# 23352  4vl8-5udtII      18.12.03
# 23353  H0g4JxKp4fc      18.12.03
# 23354  hB07EJhMBRs      18.12.03
# 23355  i04pYZGDHIc      18.12.03
# 23356  73_OWzBr8Fo      18.12.03
# 23357  pH7VfJDq7f4      18.12.03
# 23358  hV-yHbbrKRA      18.12.03
# 23359  CwKp6Xhy3_4      18.12.03
# 23360  vQiiNGllGQo      18.12.03
# 23361  2afSbqlp5HU      18.12.03
#
#                                                    title  \
# 23352                    Voice Activated Hot Dog Blaster
# 23353                                            *cough*
# 23354  A Dad Didn't Brush His Teeth For 40 Days. This...
# 23355  How To Make a CHINESE FRIED RICE TAKEOUT CAKE ...
# 23356  Made in Miami (Artist Spotlight Story) - Camil...
# 23357                                Why Bridges Move...
# 23358                      Macaroni - A Recipe From 1784
# 23359                           Chris Young - Hangin' On
# 23360      Elderly man making sure his dog won't get wet
# 23361         How to speak like Black Panther - BBC News
#
#                  channel_title  category_id        publish_time  \
# 23352            William Osman           28 2018-02-27 14:00:00
# 23353               jacksfilms           23 2018-02-26 19:00:02
# 23354                Chubbyemu           28 2018-02-26 20:00:02
# 23355           How To Cake It           26 2018-02-27 16:00:18
# 23356           Camila Cabello           10 2018-02-27 16:00:06
# 23357    Practical Engineering           27 2018-02-27 12:00:08
# 23358                Townsends           27 2018-02-26 21:23:39
# 23359           ChrisYoungVEVO           10 2018-02-26 08:00:02
# 23360  Rock me, Joey Santiago.           15 2018-02-26 11:09:32
# 23361                 BBC News            1 2018-02-27 12:26:49
#
#                                                     tags    views   likes  \
# 23352  laser cutter|"william osman"|"crappy science"|...   300425   17789
# 23353  Jacksfilms|"Jack Douglass"|"YGS"|"YGS 100"|"YG...  2292736  224986
# 23354  medicine|"medical"|"education"|"science"|"tech...   564757   25726
# 23355  Google|"YouTube"|"Yolanda Gampp"|"Yolanda Gamp...   867000   27419
# 23356  camila cabello|"camila"|"youtube music"|"docum...  1432969  140312
# 23357  thermal expansion|"expansion joint"|"thermal m...   456470   14826
# 23358  townsends|"jas townsend and son"|"reenacting"|...   519220   13600
# 23359  Losing sleep video|"losing sleep album"|"think...  1117570    7504
# 23360  dog|"cute"|"adorable"|"doggo"|"doge"|"old"|"ma...   713574   12448
# 23361  bbc|"bbc news"|"news"|"black panther"|"black p...   422979    7408
#
#        dislikes  comment_count  \
# 23352       165           2461
# 23353      8689          41467
# 23354      1014           5280
# 23355       373           2808
# 23356      1523          10472
# 23357       279            820
# 23358       329           1350
# 23359       584            324
# 23360       146           1474
# 23361      1344           1548
#
#                                        thumbnail_link  comments_disabled  \
# 23352  https://i.ytimg.com/vi/4vl8-5udtII/default.jpg              False
# 23353  https://i.ytimg.com/vi/H0g4JxKp4fc/default.jpg              False
# 23354  https://i.ytimg.com/vi/hB07EJhMBRs/default.jpg              False
# 23355  https://i.ytimg.com/vi/i04pYZGDHIc/default.jpg              False
# 23356  https://i.ytimg.com/vi/73_OWzBr8Fo/default.jpg              False
# 23357  https://i.ytimg.com/vi/pH7VfJDq7f4/default.jpg              False
# 23358  https://i.ytimg.com/vi/hV-yHbbrKRA/default.jpg              False
# 23359  https://i.ytimg.com/vi/CwKp6Xhy3_4/default.jpg              False
# 23360  https://i.ytimg.com/vi/vQiiNGllGQo/default.jpg              False
# 23361  https://i.ytimg.com/vi/2afSbqlp5HU/default.jpg              False
#
#        ratings_disabled  video_error_or_removed  \
# 23352             False                   False
# 23353             False                   False
# 23354             False                   False
# 23355             False                   False
# 23356             False                   False
# 23357             False                   False
# 23358             False                   False
# 23359             False                   False
# 23360             False                   False
# 23361             False                   False
#
#                                              description
# 23352  Thanks to Dollar Shave Club for sponsoring thi...
# 23353  If you like those shirts, you can get em here ...
# 23354  Please pardon my German... and my Chinese... A...
# 23355  My Cakebook Is Available WORLDWIDE! http://bit...
# 23356  Directed by Tabitha Denholm and Produced by Yo...
# 23357  ...and other musings on thermal movement of la...
# 23358  Visit Our Website! ▶ http://www.townsends.us/ ...
# 23359  Chris Young's Hangin' On from his #1 album Los...
# 23360  very wholesome stuff.\n\nThis video was taken ...
# 23361  The new marvel film Black Panther is set in th...

# %% [markdown]
# ### Step 2 - Data cleaning and prep

# %% [markdown]
# **Question 2.3**
#
# Convert the `trending_date` field to an actual datetime data type using the `to_datetime()` function. Show that it worked with the `.info()` method for data frames. Then compute the difference between `publish_time` and `trending_date` in hours. Store it in a new field called `time_to_trend`.

# %%
USvideos['trending_date'] = pd.to_datetime(USvideos['trending_date'],infer_datetime_format = True, format = '%y.%d.%m')

USvideos.info()

USvideos['time_to_trend'] = (USvideos['trending_date'] - USvideos['publish_time']).astype('timedelta64[h]')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23362 entries, 0 to 23361
# Data columns (total 16 columns):
# video_id                  23362 non-null object
# trending_date             23362 non-null datetime64[ns]
# title                     23362 non-null object
# channel_title             23362 non-null object
# category_id               23362 non-null int64
# publish_time              23362 non-null datetime64[ns]
# tags                      23362 non-null object
# views                     23362 non-null int64
# likes                     23362 non-null int64
# dislikes                  23362 non-null int64
# comment_count             23362 non-null int64
# thumbnail_link            23362 non-null object
# comments_disabled         23362 non-null bool
# ratings_disabled          23362 non-null bool
# video_error_or_removed    23362 non-null bool
# description               22929 non-null object
# dtypes: bool(3), datetime64[ns](2), int64(5), object(6)
# memory usage: 1.8+ MB

# %% [markdown]
# **Question 2.4**
#
# Create new field called the `like_ratio` that is the number of likes divided by the sum of the number of likes and dislikes. Then use then use the `describe()` method to get a quick statistical summary of this new field. Then create two more new fields:
#
# * `comment_intensity` as the ratio of comment_count and views
# * `thumbs` as the sum of likes and dislikes

# %%
USvideos['like_ratio'] = USvideos['likes'] / (USvideos['likes'] + USvideos['dislikes']) 

USvideos['like_ratio'].describe()

USvideos['comment_intensity'] = USvideos['comment_count'] / USvideos['views'] 

USvideos['thumbs'] = (USvideos['likes'] + USvideos['dislikes'])

# %% [markdown]
# ### Step 3 - Exploratory analysis with pandas
#
# Note: Ignore the fact that some videos appear more than once because they trended multiple times on different dates.

# %% [markdown]
# **Question 2.5**
#
# How many videos by channel title? Even better, sort in descending order. Here's what I get for the first few results:
#
#     channel_title
#     ESPN                                      114
#     Vox                                       113
#     Netflix                                   112
#     NBA                                       112
#     First We Feast                            111
#     The Tonight Show Starring Jimmy Fallon    109

# %%
counts_by_channel= USvideos.groupby('channel_title').size().sort_values(ascending = False)
counts_by_channel[:5]
# Out:
# channel_title
# ESPN              114
# Vox               113
# Netflix           112
# NBA               112
# First We Feast    111
# dtype: int64

# %% [markdown]
# **Question 2.6**
#
# Which channels are in the top 10 and bottom 10 for the mean of the `like_ratio` field we created above. Only consider channels with at least 5 videos in the USvideos DataFrame.
#
# Obviously you will end up with several Python statements.

# %%
like_stats = USvideos.groupby('channel_title').agg({'like_ratio': [np.size, np.mean]})
atleast_5 = like_stats['like_ratio']['size'] >= 5

like_stats[atleast_5].sort_values([('like_ratio', 'mean')], ascending=False)[:10]
like_stats[atleast_5].sort_values([('like_ratio', 'mean')], ascending=True)[0:10]
# Out:
#                          like_ratio
#                                size      mean
# channel_title
# Roy Moore for Senate            8.0  0.069982
# Sound Bites                     6.0  0.189006
# NBA Highlights · YouTube        7.0  0.202083
# 730 WVFN                        5.0  0.228439
# Tina Nguyen                     5.0  0.255903
# Just Jared Jr                   9.0  0.262602
# Diet Coke                       8.0  0.278597
# Paramount Network               8.0  0.318559
# Peloton                         5.0  0.333331
# Radio Andy                      6.0  0.375489

# %% [markdown]
# **Question 2.7**
#
# You'll notice that `category_id` is an integer. Not very informative. Thankfully, the Kaggle site included json files which map category id to a category name. Well, kind of. If you look at the json file in the data folder, you'll see that it's got some other stuff in there. However, if you explore some of the kernels in Kaggle, you might run across the following bit of code which creates a simple dictionary with the `category_id` as the key and a category name as the value. Here's the code. Your job is to figure out how it works and put a comment before each line explaining what it does.

# %%
# creates a dictionary that maps `category_id` to `category`
import json

#initializes an empty dictionary called id_to_category
id_to_category = {}

#opens the json file and calls it f for use with the lines below the function
with open('./data/US_category_id.json', 'r') as f:
    #creates a data frame and inputs the information from the json file
    data = json.load(f)
    
    #for each entry in the items list
    for category in data['items']:
        # adds an entry to the id_to_category dictionary
        # the key is a string of the 'id' number from within the json file
        # the value assigned to the key is the 'title' from within the 'snippet' list
        id_to_category[category['id']] = category['snippet']['title']

#prints the dictionary
print(id_to_category)
# Out:
# {'1': 'Film & Animation', '2': 'Autos & Vehicles', '10': 'Music', '15': 'Pets & Animals', '17': 'Sports', '18': 'Short Movies', '19': 'Travel & Events', '20': 'Gaming', '21': 'Videoblogging', '22': 'People & Blogs', '23': 'Comedy', '24': 'Entertainment', '25': 'News & Politics', '26': 'Howto & Style', '27': 'Education', '28': 'Science & Technology', '29': 'Nonprofits & Activism', '30': 'Movies', '31': 'Anime/Animation', '32': 'Action/Adventure', '33': 'Classics', '34': 'Comedy', '35': 'Documentary', '36': 'Drama', '37': 'Family', '38': 'Foreign', '39': 'Horror', '40': 'Sci-Fi/Fantasy', '41': 'Thriller', '42': 'Shorts', '43': 'Shows', '44': 'Trailers'}

# %% [markdown]
# **Question 2.8**
# Now figure out how you can use the `id_to_category` dictionary to create a new field in `USvideos` DataFrame called `category_name` containing, of course, the category name.

# %%
#convert id_to_category dictionary to data frame
#name the columns 'category_id' and 'category_name' so they match

#create new DataFrame
id_to_cat = pd.DataFrame()

#add two columns from the id_to_category dictionary
id_to_cat['category_id'] = id_to_category.keys()
id_to_cat['category_name'] = id_to_category.values()

#convert category_id to numeric so it will match in the USvideos dataframe
id_to_cat['category_id'] = pd.to_numeric(id_to_cat['category_id'])

#merge the data frames
USvideos = pd.merge(USvideos, id_to_cat)

#New column is category_name mapped to the category_id
USvideos.head()
# Out:
#       video_id trending_date  \
# 0  2kyS6SvSYSE    2017-11-14
# 1  0mlNzVSJrT0    2017-11-14
# 2  STI2fI7sKMo    2017-11-14
# 3  KODzih-pYlU    2017-11-14
# 4  8mhTWqWlQzU    2017-11-14
#
#                                                title       channel_title  \
# 0                 WE WANT TO TALK ABOUT OUR MARRIAGE        CaseyNeistat
# 1                               Me-O Cats Commercial             Nobrand
# 2  AFFAIRS, EX BOYFRIENDS, $18MILLION NET WORTH -...  Shawn Johnson East
# 3  BLIND(folded) CAKE DECORATING CONTEST (with Mo...        Grace Helbig
# 4      Wearing Online Dollar Store Makeup For A Week      Safiya Nygaard
#
#    category_id        publish_time  \
# 0           22 2017-11-13 17:13:01
# 1           22 2017-04-21 06:47:32
# 2           22 2017-11-11 15:00:03
# 3           22 2017-11-11 18:08:04
# 4           22 2017-11-11 01:19:33
#
#                                                 tags    views   likes  \
# 0                                    SHANtell martin   748374   57527
# 1                          cute|"cats"|"thai"|"eggs"    98966    2486
# 2  shawn johnson|"andrew east"|"shawn east"|"shaw...   321053    4451
# 3  itsgrace|"funny"|"comedy"|"vlog"|"grace"|"helb...   197062    7250
# 4  wearing online dollar store makeup for a week|...  2744430  115426
#
#    dislikes       ...                                        thumbnail_link  \
# 0      2966       ...        https://i.ytimg.com/vi/2kyS6SvSYSE/default.jpg
# 1       184       ...        https://i.ytimg.com/vi/0mlNzVSJrT0/default.jpg
# 2      1772       ...        https://i.ytimg.com/vi/STI2fI7sKMo/default.jpg
# 3       217       ...        https://i.ytimg.com/vi/KODzih-pYlU/default.jpg
# 4      1110       ...        https://i.ytimg.com/vi/8mhTWqWlQzU/default.jpg
#
#   comments_disabled  ratings_disabled  video_error_or_removed  \
# 0             False             False                   False
# 1             False             False                   False
# 2             False             False                   False
# 3             False             False                   False
# 4             False             False                   False
#
#                                          description time_to_trend  \
# 0  SHANTELL'S CHANNEL - https://www.youtube.com/s...           6.0
# 1  Kittens come out of the eggs in a Thai commerc...        4961.0
# 2  Subscribe for weekly videos ▶ http://bit.ly/sj...          56.0
# 3  Molly is an god damn amazing human and she cha...          53.0
# 4  I found this online dollar store called ShopMi...          70.0
#
#    like_ratio  comment_intensity  thumbs   category_name
# 0    0.950970           0.021318   60493  People & Blogs
# 1    0.931086           0.005376    2670  People & Blogs
# 2    0.715250           0.002788    6223  People & Blogs
# 3    0.970939           0.002314    7467  People & Blogs
# 4    0.990475           0.002383  116536  People & Blogs
#
# [5 rows x 21 columns]

# %% [markdown]
# **Question 2.9**
# Then, use the `describe()` method along with `group_by` (and maybe `unstack()`) to compute summary statistics of the `views` field, grouping by `category_name`.

# %%
USvideos.groupby('category_name')['views'].describe()
# Out:
#                         count          mean           std      min        25%  \
# category_name
# Autos & Vehicles        340.0  1.412712e+06  3.577258e+06   2860.0   90535.75
# Comedy                 1978.0  1.162698e+06  1.480560e+06   1807.0  183117.75
# Education              1002.0  4.889018e+05  5.199020e+05    773.0  193076.00
# Entertainment          5379.0  1.354847e+06  5.632033e+06    798.0  113187.50
# Film & Animation       1324.0  2.049144e+06  4.041941e+06    943.0   89534.50
# Gaming                  305.0  1.025884e+06  1.526447e+06   1237.0  131055.00
# Howto & Style          2241.0  6.562508e+05  1.969530e+06   1107.0  114523.00
# Music                  3366.0  2.555946e+06  6.126164e+06   1591.0  179866.25
# News & Politics        1907.0  3.327692e+05  5.895683e+05    549.0   32435.50
# Nonprofits & Activism    48.0  3.462797e+06  7.679870e+06   1456.0    8449.25
# People & Blogs         1886.0  1.075469e+06  3.692628e+06    884.0  126184.50
# Pets & Animals          593.0  5.538671e+05  8.100717e+05   3393.0   99681.00
# Science & Technology   1477.0  9.361251e+05  2.051200e+06    983.0  135427.00
# Shows                    16.0  1.274492e+05  5.229741e+04  36609.0   71026.25
# Sports                 1238.0  1.310862e+06  3.255911e+06    658.0   88869.25
# Travel & Events         262.0  8.613965e+05  2.355349e+06    789.0  114057.75
#
#                             50%         75%          max
# category_name
# Autos & Vehicles       356956.0  1057622.50   25244097.0
# Comedy                 614006.0  1583905.25   17758014.0
# Education              340437.0   572224.50    3675806.0
# Entertainment          373328.0  1066109.50  149376127.0
# Film & Animation       709876.0  2120290.75   36152111.0
# Gaming                 529512.0  1392641.00   10256746.0
# Howto & Style          295725.0   726343.00   54155921.0
# Music                  583419.5  2055056.25  102012605.0
# News & Politics        141605.0   420946.50    5755949.0
# Nonprofits & Activism   33214.5   296106.00   24286474.0
# People & Blogs         278930.5   895435.00   56111957.0
# Pets & Animals         296542.0   634596.00    6187457.0
# Science & Technology   343273.0   930513.00   20658640.0
# Shows                  149911.0   171546.25     179723.0
# Sports                 283570.5  1009864.00   29090799.0
# Travel & Events        355839.5   843136.75   23932421.0

# %% [markdown]
# ### Step 4 - Basic plotting in Python
#
# Feel free to use either matplotlib, pandas or Seaborn (or any combination of) to create the following basic plots.

# %%
# %matplotlib inline

data = USvideos['views']
# Create a histogram of number of views
plt.hist(data, 30, facecolor='green', alpha=0.5)
plt.xlabel('Views')
plt.ylabel('Count')
plt.title('Histogram of Number of Views')
plt.show()

# %%
# Create a histogram of the log of number of views
plt.hist(data, 30, facecolor='green', alpha=0.5, log = True)
plt.xlabel('Views')
plt.ylabel('Count')
plt.title('Histogram of the Log of Number of Views')
plt.show()

# %%
# Create a scatter plot of likes vs views

plt.scatter(USvideos['likes'], USvideos['views'])

# %%
# Create a set of boxplots of like_ratio by category
bp = USvideos.boxplot(column='like_ratio', by='category_name', vert = False)

# %%
# HACKER EXTRA - experiment with additional plots that help us understand this dataset

plt.scatter(USvideos['dislikes'], USvideos['views'])

# %% [markdown]
# ## Problem 3 - Classification
#
# Coming soon... still tidying up some details on the problem.
